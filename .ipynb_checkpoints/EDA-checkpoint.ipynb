# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv("Datasets/placement.csv")

# %%
data.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(11, 3))

for ax, key in zip(axes.flatten(), data.keys()):
    ax.set_title(key)
    sns.histplot(data[key], bins=20, kde=True, ax=ax)

plt.tight_layout()

# %%
sns.scatterplot(x="cgpa", y="placement_exam_marks", hue="placed", data=data, palette={0: "red", 1: "blue"})
# Out:
# <Axes: xlabel='cgpa', ylabel='placement_exam_marks'>
