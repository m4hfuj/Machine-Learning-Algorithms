# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv("Datasets/house_price.csv")

# %%
data.head()
# Out:
#    area  rooms   price
# 0  2104      3  399900
# 1  1600      3  329900
# 2  2400      3  369000
# 3  1416      2  232000
# 4  3000      4  539900

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(11, 3))

for ax, key in zip(axes.flatten(), data.keys()):
    ax.set_title(key)
    sns.histplot(data[key], bins=10, kde=True, ax=ax)

plt.tight_layout()

# %%
sns.scatterplot(x="cgpa", y="placement_exam_marks", hue="placed", data=data, palette={0: "red", 1: "blue"})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sns.scatterplot(x="cgpa", y="placement_exam_marks", hue="placed", data=data, palette={0: "red", 1: "blue"})
#
# File ~/env_base/lib/python3.10/site-packages/seaborn/relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     612     **kwargs
#     613 ):
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#     618         legend=legend
#     619     )
#     621     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
# ...
